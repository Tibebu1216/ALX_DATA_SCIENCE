# %% [markdown]
# <a href="https://colab.research.google.com/github/Tibebu1216/ALX_DATA_SCIENCE/blob/main/Movie_Recommendation_Project_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Movie Recommendation Project 2026**

# %%
# ==========================================
# STEP 1: INSTALL & IMPORT DEPENDENCIES
# ==========================================
# !pip install scikit-surprise tqdm

import pandas as pd
import numpy as np
import os
from scipy.sparse import csr_matrix
from surprise import SVD, Reader, Dataset
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 49.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Kaggle Authentication
#
# To download datasets from Kaggle, you need to authenticate using your Kaggle API token. Follow these steps:
#
# 1.  **Generate Kaggle API Token**: Go to your Kaggle account (https://www.kaggle.com/<your-username>/account). Under the 'API' section, click on 'Create New API Token'. This will download a `kaggle.json` file.
# 2.  **Upload `kaggle.json`**: Upload this `kaggle.json` file directly to your Colab environment. You can do this by clicking the 'Files' icon on the left sidebar, then clicking 'Upload to session storage' and selecting your `kaggle.json` file. Ensure it is uploaded to the *current working directory* (usually `/content/`) so the `mv` command can find it.
# 3.  **Run the following code cell** to set up the authentication.

# %%
import os

# Create the .kaggle directory if it doesn't exist
# !mkdir -p ~/.kaggle

# Move the kaggle.json file to the .kaggle directory
# Assuming you have uploaded kaggle.json to your Colab session storage
# If you manually created the file, this step might be different.
# !mv kaggle.json ~/.kaggle/

# Set permissions for the kaggle.json file
# !chmod 600 ~/.kaggle/kaggle.json

print('Kaggle API key configured successfully!')
# Out:
# mv: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory
# Kaggle API key configured successfully!

# %%
# Used to securely store your API key
from google.colab import userdata

# Create the .kaggle directory if it doesn't exist
# !mkdir -p ~/.kaggle

# Get Kaggle credentials from Colab Secrets
kaggle_username = userdata.get('KAGGLE_USERNAME')
kaggle_key = userdata.get('KAGGLE_KEY')

# Write the kaggle.json file with the correct 'username' key
with open('/root/.kaggle/kaggle.json', 'w') as f:
    f.write('{"username":"' + kaggle_username + '","key":"' + kaggle_key + '"}')

# Set permissions for the kaggle.json file
# !chmod 600 ~/.kaggle/kaggle.json

print('Kaggle API key configured successfully from Colab Secrets!')
# Out:
# Kaggle API key configured successfully from Colab Secrets!

# %% [markdown]
# After successfully configuring your Kaggle API key, you can re-run the data download cell.

# %%
# ==========================================
# STEP 2: LOAD COMPETITION DATASETS
# ==========================================
# (If using Google Drive, prepend your path e.g., '/content/drive/MyDrive/')
print("Loading core datasets...")
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

print(f"Train Shape: {train.shape}")
print(f"Test Shape: {test.shape}")

# Calculate global mean rating to fallback on for absolute cold-start exceptions
global_mean_rating = train['rating'].mean()
# Out:
# Loading core datasets...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4121/1597324609.py in <cell line: 0>()
#       4 # (If using Google Drive, prepend your path e.g., '/content/drive/MyDrive/')
#       5 print("Loading core datasets...")
# ----> 6 train = pd.read_csv('train.csv')
#       7 test = pd.read_csv('test.csv')
#       8
#
# ...
